# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls').head(100)
# Out:
#                           Country/Region/World  ISO  Sex    Year   Mean BMI  \
# 0                   Central and Eastern Europe  NaN  Men  1975.0  24.263785
# 1                   Central and Eastern Europe  NaN  Men  1976.0  24.325576
# 2                   Central and Eastern Europe  NaN  Men  1977.0  24.386033
# 3                   Central and Eastern Europe  NaN  Men  1978.0  24.446015
# 4                   Central and Eastern Europe  NaN  Men  1979.0  24.505324
# 5                   Central and Eastern Europe  NaN  Men  1980.0  24.564228
# 6                   Central and Eastern Europe  NaN  Men  1981.0  24.621296
# 7                   Central and Eastern Europe  NaN  Men     NaN  24.676361
# 8                   Central and Eastern Europe  NaN  Men  1983.0  24.729492
# 9                   Central and Eastern Europe  NaN  Men  1984.0  24.780281
# 10                  Central and Eastern Europe  NaN  Men  1985.0  24.827156
# ...

# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
missing_vals = ["NaN"]
dataset1 = pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls', na_values = missing_vals)
dataset1.isnull().sum()
# Out:
# Country/Region/World                                                          0
# ISO                                                                         756
# Sex                                                                           2
# Year                                                                          5
# Mean BMI                                                                     10
# Mean BMI lower 95% uncertainty interval                                      11
# Mean BMI upper 95% uncertainty interval                                       1
# Prevalence of BMI>=30 kg/m² (obesity)                                         1
# Prevalence of BMI>=30 kg/m² lower 95% uncertainty interval                    0
# Prevalence of BMI>=30 kg/m² upper 95% uncertainty interval                    0
# Prevalence of BMI>=35 kg/m² (severe obesity)                                  1
# Prevalence of BMI>=35 kg/m² lower 95% uncertainty interval                    0
# ...

# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
missing_vals = ["NaN"]
dataset1 = pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls', na_values = missing_vals)
dataset1.isnull().sum().sum()
# Out:
# 787

# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
missing_vals = ["NaN"]
dataset1 = pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls', na_values = missing_vals)
dataset1.loc[7,"Year"] = 1982
dataset1.loc[20,"Year"] = 1995
dataset1.head(100)
# Out:
#                           Country/Region/World  ISO  Sex    Year   Mean BMI  \
# 0                   Central and Eastern Europe  NaN  Men  1975.0  24.263785
# 1                   Central and Eastern Europe  NaN  Men  1976.0  24.325576
# 2                   Central and Eastern Europe  NaN  Men  1977.0  24.386033
# 3                   Central and Eastern Europe  NaN  Men  1978.0  24.446015
# 4                   Central and Eastern Europe  NaN  Men  1979.0  24.505324
# 5                   Central and Eastern Europe  NaN  Men  1980.0  24.564228
# 6                   Central and Eastern Europe  NaN  Men  1981.0  24.621296
# 7                   Central and Eastern Europe  NaN  Men  1982.0  24.676361
# 8                   Central and Eastern Europe  NaN  Men  1983.0  24.729492
# 9                   Central and Eastern Europe  NaN  Men  1984.0  24.780281
# 10                  Central and Eastern Europe  NaN  Men  1985.0  24.827156
# ...

# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls').head(1)
# Out:
#          Country/Region/World  ISO  Sex    Year   Mean BMI  \
# 0  Central and Eastern Europe  NaN  Men  1975.0  24.263785
#
#    Mean BMI lower 95% uncertainty interval  \
# 0                                23.271552
#
#    Mean BMI upper 95% uncertainty interval  \
# 0                                25.284745
#
#    Prevalence of BMI>=30 kg/m² (obesity)  \
# 0                               0.064347
#
#    Prevalence of BMI>=30 kg/m² lower 95% uncertainty interval  \
# 0                                           0.040008
#
#    Prevalence of BMI>=30 kg/m² upper 95% uncertainty interval  \
# 0                                           0.097944
#
#                               ...                               \
# 0                             ...
#
#    Prevalence of BMI 25 kg/m² to <30 kg/m² upper 95% uncertainty interval  \
# 0                                           0.399219
#
#    Prevalence of BMI 30 kg/m² to <35 kg/m²  \
# 0                                 0.058782
#
# ...

# %%
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
dataset=pd.read_excel(r'C:\Users\laoyy\Desktop\BMI_Regional_Data.xls')
dataset.drop("ISO", axis=1, inplace=True)
dataset.head()
# Out:
#          Country/Region/World  Sex    Year   Mean BMI  \
# 0  Central and Eastern Europe  Men  1975.0  24.263785
# 1  Central and Eastern Europe  Men  1976.0  24.325576
# 2  Central and Eastern Europe  Men  1977.0  24.386033
# 3  Central and Eastern Europe  Men  1978.0  24.446015
# 4  Central and Eastern Europe  Men  1979.0  24.505324
#
#    Mean BMI lower 95% uncertainty interval  \
# 0                                23.271552
# 1                                23.413005
# 2                                23.545070
# 3                                23.666635
# 4                                23.789155
#
#    Mean BMI upper 95% uncertainty interval  \
# 0                                25.284745
# 1                                25.263278
# 2                                25.255912
# 3                                25.253508
# 4                                25.254154
#
#    Prevalence of BMI>=30 kg/m² (obesity)  \
# 0                               0.064347
# ...
